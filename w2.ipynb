# %%
from skimage import data,io,color
from matplotlib import pyplot as plt
import numpy as np

# %%
image = plt.imread('Ims/DALL·E4.png')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.size
# Out:
# 3145728

# %%
image.shape
# Out:
# (1024, 1024, 3)

# %%
plt.imshow(image)
plt.title('Tavşan')
plt.axis('off')
plt.show()

# %%
vertical_image = np.flipud(image)

# %%
plt.imshow(vertical_image)
plt.title('Tavşan_Ters')
plt.axis('off')
plt.show()

# %%
horizontal_image = np.fliplr(image)

# %%
plt.imshow(horizontal_image)
plt.title('Tavşan_Yatay')
plt.axis('off')
plt.show()

# %%
image = plt.imread('Ims/DALL·E15.png')
plt.imshow(image)
plt.title('IMAGE')
plt.axis('off')
plt.show()

# %%
red_channel = image[:,:,0]

plt.hist(red_channel.ravel(), bins=256)

plt.title('Red Histogram')
plt.show()

# %%
blue_channel = image[:,:,2]

plt.hist(blue_channel.ravel(), bins=256)

plt.title('Blue Histogram')
plt.show()
