# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
img = np.asarray(Image.open('Ims/DALL·E15.png'))
img
# Out:
# array([[[ 11,  23,  35, 255],
#         [ 11,  23,  35, 255],
#         [ 13,  24,  36, 255],
#         ...,
#         [ 11,  25,  36, 255],
#         [ 51,  51,  51, 255],
#         [ 51,  51,  51, 255]],
#
#        [[ 11,  23,  35, 255],
#         [ 11,  23,  35, 255],
#         [ 13,  24,  36, 255],
#         ...,
#         [ 11,  25,  36, 255],
#         [ 51,  51,  51, 255],
#         [ 51,  51,  51, 255]],
#
#        [[ 11,  23,  35, 255],
#         [ 11,  23,  35, 255],
#         [ 13,  24,  36, 255],
#         ...,
#         [ 11,  25,  37, 255],
#         [ 51,  51,  51, 255],
#         [ 51,  51,  51, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [ 37,  18,  15, 255],
#         [ 33,  22,  21, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
imgplot = plt.imshow(img)

# %%
lum_img = img[:, :, 0]
plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %%
plt.hist(lum_img.ravel(), bins=range(256))
# Out:
# (array([   60.,   452.,   344.,  1330.,   897.,  1190.,  1336.,  1259.,
#           795.,   787.,   980.,  3650., 12855., 15949., 14692., 13247.,
#          9811.,  7560.,  5388.,  3917.,  2172.,  1488.,  1297.,  1181.,
#          1287.,  1382.,  1304.,  1171.,  1316.,  1230.,  1564.,  2721.,
#          5209.,  6321.,  5075.,  3760.,  3137.,  3085.,  2824.,  3129.,
#          3292.,  2620.,  2182.,  2244.,  1990.,  2429.,  2292.,  1860.,
#          1838.,  1852.,  2230.,  2049.,  2024.,  2081.,  1824.,  1394.,
#          1055.,  1006.,   918.,  1058.,  1049.,  1128.,  1347.,  1405.,
#          1542.,  1000.,   612.,   512.,   286.,   270.,   247.,   261.,
#           276.,   273.,   304.,   343.,   282.,   295.,   372.,   266.,
#           244.,   243.,   202.,   193.,   220.,   237.,   216.,   190.,
#           205.,   198.,   179.,   151.,   196.,   169.,   161.,   156.,
#           130.,   131.,    95.,    79.,    68.,    71.,   100.,    86.,
# ...

# %%
#plt.imshow(lum_img, clim=(0, 100))

# %%
img = Image.open('Ims/DALL·E15.png') # henüz numpy dizisi yapmadığımıza dikkat edin.
img.thumbnail((64, 64))  # resizes image in-place -- default interpolation ("nearest")
imgplot = plt.imshow(img)

# %%
imgplot = plt.imshow(img, interpolation="bilinear")

# %%
imgplot = plt.imshow(img, interpolation="bicubic")
